# %%
from IPython.display import Latex

import numpy as np
from scipy.integrate import simps
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (9, 6)

from scipy.optimize import curve_fit
from scipy.constants import hbar, m_p, e

# from matplotlib.backends.backend_pdf import PdfPages
# pdf = PdfPages('ho.pdf')

# %% [markdown]
# # Theoretical background
# Numerov's algorithm in matrix form is:
#
# $$
# H \, u = \left(-\frac{1}{2} B^{-1} A + V \right) u = E \, u
# $$
#
# where:
#
# $$
# A_{ij} = \frac{1}{\Delta r^2} \left( \delta_{i+1,j}  -2 \, \delta_{i,j} + \delta_{i-1,j} \right)
# \,, \qquad
# B_{ij} = \frac{1}{12} \left( \delta_{i+1,j} + 10 \, \delta_{i,j} + \delta_{i-1,j} \right)
# \,, \qquad
# V = \mathrm{diag}(V_0, V_1, \dots, V_{N-1})
# $$
#
# in order to find the eigenvalues and the eigenfunctions one only needs only to diagonalize the discrete hamiltonian $H$.

# %%
def V_ho(r,l):
    out = 0.5 * r**2 + l*(l+1)/(2 * r**2)
    return out

def V_hy(r, l):
    return - 1/r + l*(l+1)/(2 * r**2)

def mat_sandwich(n, diag_val):
    mat = diag_val * np.eye(n) 
    mat += np.eye(n,k=1)
    mat += np.eye(n,k=-1)
    return mat

def normalize_psi(psi, x):
    psi_sq = simps(abs(psi) ** 2, x)
    return psi / np.sqrt(psi_sq)

# %% [markdown]
# # 1. 1D harmonic oscillator via Numerov algorithm

# %%
nptx = 1000
xgrid = np.linspace(-5-1e-3, 5, nptx) 
dx = 10/nptx

B = mat_sandwich(nptx,10) / 12
Binv = np.linalg.inv(B)
A = mat_sandwich(nptx, -2) / (dx**2)
KE = - Binv @ A / 2

# %%
l=0

H_ho = KE + np.diag(V_ho(xgrid, l))
E_ho , wf_ho = np.linalg.eigh(H_ho) # solve eigensystem
wf_ho = normalize_psi(wf_ho, xgrid)

n = np.arange(0, 5)
E_ho_th = (n + 1/2)

for i in range(5):
    plt.plot(xgrid, np.sign(wf_ho[0, i])*wf_ho[:, i], label=f'n = {i}')
    plt.grid(True)
    plt.legend()

plt.xlabel("r", fontsize=14)
plt.ylabel("u(r)", fontsize=14)
# pdf.savefig()
plt.show()

display(Latex('$E_{\\text{Num}}$ | $E_{Th}$'))
for i in range(5):
    print(round(E_ho[i], 3), '|', E_ho_th[i])
# Out:
# $E_{\text{Num}}$ | $E_{Th}$
# 0.501 | 0.5
# 1.502 | 1.5
# 2.503 | 2.5
# 3.504 | 3.5
# 4.505 | 4.5

# %%
l=0

nptxx =  np.linspace(10, 1000, 50)
E_g = np.zeros(np.size(nptxx))

for i in range(np.size(nptxx)):
    nptx = np.int(nptxx[i])
    xgrid = np.linspace(-5-1e-3, 5, nptx) 
    dx = 10/nptx

    B = mat_sandwich(nptx, 10) / 12
    Binv = np.linalg.inv(B)
    A = mat_sandwich(nptx, -2) / (dx**2)
    KE = - Binv @ A / 2

    H_ho = KE + np.diag(V_ho(xgrid, l))
    E_ho , wf_ho = np.linalg.eigh(H_ho) # solve eigensystem
    
    E_g[i] = np.min(E_ho)
    
plt.scatter(nptxx, E_g, marker='.', label="Numerov's method", s=50)
plt.grid(True)

f = lambda x, a, b, c: a / x**b + c

popt, pcov = curve_fit(f, nptxx, E_g)
perr = np.sqrt(np.diag(pcov))

display(Latex(f'$E_0 = {popt[2]:.5f} \pm {perr[2]:.5f}$'))

x = np.linspace(10, 1000, 200)
plt.plot(x, f(x, *popt), label='Fit', c='tab:orange')

plt.plot(nptxx, 0.5*np.ones(np.size(nptxx)), color='tab:green', label="Theoretical value")

plt.xlabel("N", fontsize=14)
plt.ylabel("$E_0$", fontsize=14)
plt.legend()

# pdf.savefig()
plt.show()
# Out:
# $E_0 = 0.49998 \pm 0.00001$

# %% [markdown]
# # 2. 3D harmonic oscillator via Numerov

# %%
dr = 0.05
npt = 1005
rgrid = np.arange(1, npt+1) * dr
B = mat_sandwich(npt, 10) / 12
Binv = np.linalg.inv(B)
A = mat_sandwich(npt,-2) / (dr**2)
KE = - Binv @ A / 2

# %%
plt.figure(figsize=(18, 6))

for l in range(3):
    plt.subplot(int(f'13{l+1}'))
    H_3d = KE + np.diag(V_ho(rgrid, l))
    E_3d , wf_3d = np.linalg.eigh(H_3d) # solve eigensystem
    wf_3d = normalize_psi(wf_3d, rgrid)
    
    for i in range(3):
        plt.plot(rgrid, wf_3d[:,i], label=f'k = {i}')

    plt.xlabel("r", fontsize=14)
    plt.ylabel("u(r)", fontsize=14)
    plt.title(f"$\ell$ = {l}", fontsize=16)
    plt.xlim(0, 10)

    plt.grid(True)
    plt.legend()
    
    k = np.arange(0, 3)
    E_3d_th = (2*k + l + 3/2)
    
    display(Latex(f'$E_{{\\text{{Num}}}}^{{\ell = {l}}}$ | $E_{{Th}}^{{\ell = {l}}}$'))
    for i in range(3):
        print(round(E_3d[i], 3), '|', E_3d_th[i])

# pdf.savefig()
# Out:
# $E_{\text{Num}}^{\ell = 0}$ | $E_{Th}^{\ell = 0}$
# 1.5 | 1.5
# 3.5 | 3.5
# 5.5 | 5.5
# $E_{\text{Num}}^{\ell = 1}$ | $E_{Th}^{\ell = 1}$
# 2.5 | 2.5
# 4.5 | 4.5
# 6.5 | 6.5
# $E_{\text{Num}}^{\ell = 2}$ | $E_{Th}^{\ell = 2}$
# 3.5 | 3.5
# 5.5 | 5.5
# 7.5 | 7.5

# %% [markdown]
# # 3. Bessel functions using the recursion formulae

# %%
def bessel(l, x):
    if l == 0:
        return np.sin(x) / x
    if l == 1:
        return np.sin(x)/(x**2) - np.cos(x)/x
    return (2*l - 1)/x * bessel(l-1, x) - bessel(l-2, x)

def neumann(l, x):
    if l == 0:
        return - np.cos(x)/x
    if l == 1:
        return - np.cos(x)/(x**2) - np.sin(x)/x
    return (2*l - 1)/x * neumann(l-1, x) - neumann(l-2, x)

plt.figure(figsize=(18, 6))
axB = plt.subplot(121)
axN = plt.subplot(122)

x = np.linspace(1e-3, 10)

for l in range(3):
    axB.plot(x, bessel(l, x), label=f'$\ell$ = {l}')
    axN.plot(x, neumann(l, x), label=f'$\ell$ = {l}')
    
axB.set_title('Bessel', fontsize=16)
axN.set_title('Neumann', fontsize=16)

axB.set_xlabel('x', fontsize=14)
axN.set_xlabel('x', fontsize=14)

axB.set_ylabel('$j_l (x)$', fontsize=14)
axN.set_ylabel('$\eta_l (x)$', fontsize=14)

axN.set_ylim(-1.5, 0.5)

axB.grid()
axN.grid()

axB.legend()
axN.legend(loc='lower right')

# pdf.savefig()
plt.show()

# %%
# pdf.close()
